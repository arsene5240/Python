# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 37, 25, 38])

# %%
plt.plot([1, 2, 3, 4], [-4, 5, 6, 2])

# %%
plt.scatter([1, 2, 3, 4], [-4, 5, 6, 2])

# %%
plt.plot(np.random.randn(100))

# %%
x = np.linspace(0, 10, 1000)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
x=np.linspace(-2,0,1000)
x2=np.linspace(0,2,1000)
y=-np.square(x+1)+3
y2=-np.square(x+1)+3
x3=np.linspace(-2,2,2000)
y3=np.abs(x3)
plt.plot(x,y,'r')
plt.plot(x2,y2,'r')
plt.plot(x3,y3,'r')
